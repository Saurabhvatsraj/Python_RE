# %%
import pandas as pd

# %%
x={
    "name":["gaurav","rahul","rohit"],
    "age":[23,30,40],
    "marks":[70,77,81]
}
x
# Out:
# {'name': ['gaurav', 'rahul', 'rohit'],
#  'age': [23, 30, 40],
#  'marks': [70, 77, 81]}

# %%
type(x)
# Out:
# dict

# %%
df=pd.DataFrame(x)

# %%
df
# Out:
#      name  age  marks
# 0  gaurav   23     70
# 1   rahul   30     77
# 2   rohit   40     81

# %%
#change the name or marks in this data
# changing the name
df['name'][1]="vinit"
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_21932\3176592607.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['name'][1]="vinit"

# %%
df
# Out:
#      name  age  marks
# 0  gaurav   23     70
# 1   vinit   30     77
# 2   rohit   40     81

# %%
# change the marks of rohit

df['marks'][2]=20
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_21932\2585309845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marks'][2]=20

# %%
df
# Out:
#      name  age  marks
# 0  gaurav   23     70
# 1   vinit   30     77
# 2      20   40     20

# %%
df["name"][2]="rohit"
df
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_21932\4073123994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["name"][2]="rohit"
#      name  age  marks
# 0  gaurav   23     70
# 1   vinit   30     77
# 2   rohit   40     20

# %%
# storing the data
# use csv file to store the data
# read the file/store the file

file=df.to_csv("myfirstfile.csv")

# %%
file

# %%
#wap to store df into excel file.

file=df.to_excel("mysecondfile.xlsx",index=False)

# %%
file

# %%
# how to read the data-----

df=pd.read_csv(r'C:\Users\saura\Downloads\Unicorn_Companies.csv')

# %%
df
# Out:
#            Company Valuation ($B) Date Joined        Country           City  \
# 0        Bytedance           $140    4/7/2017          China        Beijing
# 1           SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2           Stripe            $95   1/23/2014  United States  San Francisco
# 3           Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4       Epic Games            $42  10/26/2018  United States           Cary
# ...            ...            ...         ...            ...            ...
# 1032     Timescale             $1   2/22/2022  United States       New York
# 1033      Scalapay             $1   2/23/2022          Italy          Milan
# 1034  Omada Health             $1   2/23/2022  United States  San Francisco
# 1035    BlueVoyant             $1   2/23/2022  United States       New York
# 1036          Veev             $1   2/24/2022  United States      San Mateo
#
#                           Industry  \
# ...

# %%
#head
# tail
#sample

df.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
df.head(10)
# Out:
#         Company Valuation ($B) Date Joined         Country           City  \
# 0     Bytedance           $140    4/7/2017           China        Beijing
# 1        SpaceX         $100.3   12/1/2012   United States      Hawthorne
# 2        Stripe            $95   1/23/2014   United States  San Francisco
# 3        Klarna          $45.6  12/12/2011          Sweden      Stockholm
# 4    Epic Games            $42  10/26/2018   United States           Cary
# 5         Canva            $40    1/8/2018       Australia    Surry Hills
# 6  Checkout.com            $40    5/2/2019  United Kingdom         London
# 7     Instacart            $39  12/30/2014   United States  San Francisco
# 8    Databricks            $38    2/5/2019   United States  San Francisco
# 9       Revolut            $33   4/26/2018  United Kingdom         London
#
#                               Industry  \
# 0              Artificial intelligence
# 1                                Other
# ...

# %%
df.tail()
# Out:
#            Company Valuation ($B) Date Joined        Country           City  \
# 1032     Timescale             $1   2/22/2022  United States       New York
# 1033      Scalapay             $1   2/23/2022          Italy          Milan
# 1034  Omada Health             $1   2/23/2022  United States  San Francisco
# 1035    BlueVoyant             $1   2/23/2022  United States       New York
# 1036          Veev             $1   2/24/2022  United States      San Mateo
#
#                           Industry  \
# 1032  Internet software & services
# 1033                       Fintech
# 1034                        Health
# 1035                 Cybersecurity
# 1036  Internet software & services
#
#                                       Select Inverstors Founded Year  \
# 1032  New Enterprise Associates, Benchmark, Two Sigm...         2015
# 1033  Fasanara Capital, Tiger Global Management, Bal...         2019
# 1034  U.S. Venture Partners, dRx Capital, Andreessen...         2011
# ...

# %%
df.tail(10)
# Out:
#            Company Valuation ($B) Date Joined         Country           City  \
# 1027       Payhawk             $1   2/14/2022  United Kingdom         London
# 1028     Watershed             $1    2/8/2022   United States  San Francisco
# 1029        Axelar             $1   2/15/2022          Canada       Waterloo
# 1030          CHEQ             $1   2/22/2022   United States       New York
# 1031        Hasura             $1   2/22/2022           India      Bengaluru
# 1032     Timescale             $1   2/22/2022   United States       New York
# 1033      Scalapay             $1   2/23/2022           Italy          Milan
# 1034  Omada Health             $1   2/23/2022   United States  San Francisco
# 1035    BlueVoyant             $1   2/23/2022   United States       New York
# 1036          Veev             $1   2/24/2022   United States      San Mateo
#
#                           Industry  \
# 1027                       Fintech
# 1028  Internet software & services
# ...

# %%
df.sample()
# Out:
#            Company Valuation ($B) Date Joined Country     City  \
# 319  Xinchao Media             $2    4/9/2018   China  Chengdu
#
#                          Industry                   Select Inverstors  \
# 319  Internet software & services  JD.com, Baidu, Vision Plus Capital
#
#     Founded Year Total Raised Financial Stage Investors Count Deal Terms  \
# 319         2007       $1.33B             IPO               8          4
#
#     Portfolio Exits
# 319               1

# %%
df.sample(3)
# Out:
#                     Company Valuation ($B) Date Joined        Country  \
# 48   Digital Currency Group            $10   11/1/2021  United States
# 228  ChargeBee Technologies           $3.5   4/20/2021  United States
# 66                   Tempus           $8.1   3/21/2018  United States
#
#          City  Industry                                  Select Inverstors  \
# 48   New York  Finttech           Ribbit Capital, capitalG, Softbank Group
# 228    Walnut   Fintech   Insight Partners, Tiger Global Management, Accel
# 66    Chicago    Health  New Enterprise Associates, T. Rowe Associates,...
#
#     Founded Year Total Raised Financial Stage Investors Count Deal Terms  \
# 48          2018      $3.396B        Acquired              22          5
# 228         2011     $468.65M            None               6          4
# 66          2015       $1.07B            None              10          6
#
#     Portfolio Exits
# 48                1
# 228            None
# 66             None
